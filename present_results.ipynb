# %%
import os
from ultralytics import YOLO
print(os.getcwd())
model = YOLO('./runs/models/yolo11s_data4animalsV2_48epochs.pt')
# Out:
# c:\Users\Z0127829\OneDrive - ZF Friedrichshafen AG\Desktop\Arbeit\Studienarbeit\intelligente_wildkamera

# %% [markdown]
# Vorhersage auf Video: Reh

# %%
path_test = "./.data/evaluation/video/deer/deer_single.mp4"
results = model.predict(source=path_test, save=True, conf=0.2)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/484) c:\Users\Z0127829\OneDrive - ZF Friedrichshafen AG\Desktop\Arbeit\Studienarbeit\intelligente_wildkamera\src\..\.data\evaluation\video\deer\deer_single.mp4: 384x640 1 deer, 251.4ms
# video 1/1 (frame 2/484) c:\Users\Z0127829\OneDrive - ZF Friedrichshafen AG\Desktop\Arbeit\Studienarbeit\intelligente_wildkamera\src\..\.data\evaluation\video\deer\deer_single.mp4: 384x640 1 deer, 129.4ms
# ...

# %%
path_test = ".data/evaluation/video/no_deer/IMAG0157.AVI"
results = model.predict(source=path_test, save=True, conf=0.2)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/200) c:\Users\Z0127829\OneDrive - ZF Friedrichshafen AG\Desktop\Arbeit\Studienarbeit\intelligente_wildkamera\.data\evaluation\video\no_deer\IMAG0157.AVI: 480x640 1 wild_boar, 206.2ms
# video 1/1 (frame 2/200) c:\Users\Z0127829\OneDrive - ZF Friedrichshafen AG\Desktop\Arbeit\Studienarbeit\intelligente_wildkamera\.data\evaluation\video\no_deer\IMAG0157.AVI: 480x640 1 wild_boar, 156.6ms
# ...

# %% [markdown]
# Tracking

# %%
results = model.track(source=".data/evaluation/video/deer/IMAG0087.AVI", save=True, conf=0.2)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/200) c:\Users\Z0127829\OneDrive - ZF Friedrichshafen AG\Desktop\Arbeit\Studienarbeit\intelligente_wildkamera\.data\evaluation\video\deer\IMAG0087.AVI: 480x640 2 deers, 361.6ms
# video 1/1 (frame 2/200) c:\Users\Z0127829\OneDrive - ZF Friedrichshafen AG\Desktop\Arbeit\Studienarbeit\intelligente_wildkamera\.data\evaluation\video\deer\IMAG0087.AVI: 480x640 1 deer, 201.1ms
# ...
